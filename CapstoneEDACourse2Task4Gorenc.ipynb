# %%
import pandas as pd
import glob
import seaborn as sns
import numpy

# %%
#Concatenate the monthly Nest .csv output into a single, concatenated file
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
combined = pd.read_csv('combined_csv.csv')

# %%
combined.head()
# Out:
#          Date   Time  avg(temp)  avg(humidity)  max(pir)  max(nearPir)  \
# 0  2018-02-01  00:00      21.68          44.26     344.0           NaN
# 1  2018-02-01  00:15      21.77          45.97      23.0           NaN
# 2  2018-02-01  00:30      22.09          45.34      24.0           NaN
# 3  2018-02-01  00:45      21.66          45.23     428.0           NaN
# 4  2018-02-01  01:00      22.24          45.54     180.0           NaN
#
#    min(ch1)  max(ch1)  min(ch2)  max(ch2)  min(als)  max(als)  min(tp0)  \
# 0       NaN       NaN       NaN       NaN       0.0       0.0    -501.0
# 1       NaN       NaN       NaN       NaN       0.0       0.0     -50.0
# 2       NaN       NaN       NaN       NaN       0.0       0.0    -156.0
# 3       NaN       NaN       NaN       NaN       0.0       0.0    -219.0
# 4       NaN       NaN       NaN       NaN       0.0       0.0     -80.0
#
#    max(tp0)  min(tp1)  max(tp1)  min(tp2)  max(tp2)  min(tp3)  max(tp3)
# ...

# %%
combined.info
# Out:
# <bound method DataFrame.info of               Date   Time  avg(temp)  avg(humidity)  max(pir)  max(nearPir)  \
# 0       2018-02-01  00:00      21.68          44.26     344.0           NaN
# 1       2018-02-01  00:15      21.77          45.97      23.0           NaN
# 2       2018-02-01  00:30      22.09          45.34      24.0           NaN
# 3       2018-02-01  00:45      21.66          45.23     428.0           NaN
# 4       2018-02-01  01:00      22.24          45.54     180.0           NaN
# ...            ...    ...        ...            ...       ...           ...
# 373705   3/20/2020  12:15      25.55          77.47      26.0           NaN
# 373706   3/20/2020  12:30        NaN            NaN       NaN           NaN
# 373707   3/20/2020  12:45      25.47          77.77      29.0           NaN
# 373708   3/20/2020  13:00      25.41          78.14     294.0           NaN
# 373709   3/20/2020  13:15      25.40          78.77     260.0           NaN
#
# ...

# %%
combined.shape
# Out:
# (373710, 20)

# %%
combined_csv.to_csv('combinededited.csv')

# %%
nest = pd.read_csv('combinededited.csv')

# %%
nest.isnull()
# Out:
#          Date   Time  avg(temp)  avg(humidity)  max(pir)  min(als)  max(als)  \
# 0       False  False      False          False     False     False     False
# 1       False  False      False          False     False     False     False
# 2       False  False      False          False     False     False     False
# 3       False  False      False          False     False     False     False
# 4       False  False      False          False     False     False     False
# ...       ...    ...        ...            ...       ...       ...       ...
# 373705  False  False      False          False     False     False     False
# 373706  False  False       True           True      True      True      True
# 373707  False  False      False          False     False     False     False
# 373708  False  False      False          False     False     False     False
# 373709  False  False      False          False     False     False     False
#
# ...

# %%
nest.info
# Out:
# <bound method DataFrame.info of              Date   Time  avg(temp)  avg(humidity)  max(pir)  min(als)  \
# 0        2/1/2018   0:00      21.68          44.26     344.0       0.0
# 1        2/1/2018   0:15      21.77          45.97      23.0       0.0
# 2        2/1/2018   0:30      22.09          45.34      24.0       0.0
# 3        2/1/2018   0:45      21.66          45.23     428.0       0.0
# 4        2/1/2018   1:00      22.24          45.54     180.0       0.0
# ...           ...    ...        ...            ...       ...       ...
# 373705  3/20/2020  12:15      25.55          77.47      26.0       0.0
# 373706  3/20/2020  12:30        NaN            NaN       NaN       NaN
# 373707  3/20/2020  12:45      25.47          77.77      29.0       0.0
# 373708  3/20/2020  13:00      25.41          78.14     294.0       0.0
# 373709  3/20/2020  13:15      25.40          78.77     260.0       0.0
#
#         max(als)  min(tp0)  max(tp0)  min(tp1)  max(tp1)  min(tp2)  max(tp2)  \
# ...

# %%
nest.dtypes
# Out:
# Date              object
# Time              object
# avg(temp)        float64
# avg(humidity)    float64
# max(pir)         float64
# min(als)         float64
# max(als)         float64
# min(tp0)         float64
# max(tp0)         float64
# min(tp1)         float64
# max(tp1)         float64
# min(tp2)         float64
# max(tp2)         float64
# min(tp3)         float64
# max(tp3)         float64
# dtype: object

# %%
covMat = nest.corr()
print(covMat)
# Out:
#                avg(temp)  avg(humidity)  max(pir)  min(als)  max(als)  \
# avg(temp)       1.000000       0.047174  0.009602  0.068021  0.093659
# avg(humidity)   0.047174       1.000000 -0.023828  0.035843  0.010409
# max(pir)        0.009602      -0.023828  1.000000  0.072794  0.212212
# min(als)        0.068021       0.035843  0.072794  1.000000  0.609734
# max(als)        0.093659       0.010409  0.212212  0.609734  1.000000
# min(tp0)       -0.016734       0.017974 -0.724642 -0.036510 -0.151574
# max(tp0)        0.020055      -0.022165  0.879231  0.072708  0.193729
# min(tp1)       -0.015577       0.020019 -0.709183 -0.036893 -0.150396
# max(tp1)        0.021724      -0.026531  0.886531  0.074883  0.194789
# min(tp2)       -0.016434       0.022413 -0.730771 -0.043003 -0.156876
# max(tp2)        0.021858      -0.028143  0.886252  0.075311  0.196535
# min(tp3)       -0.036479       0.071342 -0.699560 -0.033562 -0.150503
# ...

# %%
corrMat = nest.corr()
print(corrMat)
# Out:
#                avg(temp)  avg(humidity)  max(pir)  min(als)  max(als)  \
# avg(temp)       1.000000       0.047174  0.009602  0.068021  0.093659
# avg(humidity)   0.047174       1.000000 -0.023828  0.035843  0.010409
# max(pir)        0.009602      -0.023828  1.000000  0.072794  0.212212
# min(als)        0.068021       0.035843  0.072794  1.000000  0.609734
# max(als)        0.093659       0.010409  0.212212  0.609734  1.000000
# min(tp0)       -0.016734       0.017974 -0.724642 -0.036510 -0.151574
# max(tp0)        0.020055      -0.022165  0.879231  0.072708  0.193729
# min(tp1)       -0.015577       0.020019 -0.709183 -0.036893 -0.150396
# max(tp1)        0.021724      -0.026531  0.886531  0.074883  0.194789
# min(tp2)       -0.016434       0.022413 -0.730771 -0.043003 -0.156876
# max(tp2)        0.021858      -0.028143  0.886252  0.075311  0.196535
# min(tp3)       -0.036479       0.071342 -0.699560 -0.033562 -0.150503
# ...

# %%
nest['avg(temp)'] = int()

# %%
nest.dtypes
# Out:
# Date              object
# Time              object
# avg(temp)          int64
# avg(humidity)    float64
# max(pir)         float64
# min(als)         float64
# max(als)         float64
# min(tp0)         float64
# max(tp0)         float64
# min(tp1)         float64
# max(tp1)         float64
# min(tp2)         float64
# max(tp2)         float64
# min(tp3)         float64
# max(tp3)         float64
# dtype: object

# %% [markdown]
# nest['avg(humidity)'] = int()

# %% [markdown]
# nest['max(pir)'] = int()

# %% [markdown]
# nest['max(nearPir)'] = int()

# %% [markdown]
# nest['min(ch1)'] = int()

# %% [markdown]
# nest['max(ch1)'] = int()

# %% [markdown]
# nest['min(ch2)'] = int()

# %% [markdown]
# nest['max(ch2)'] = int()

# %% [markdown]
# nest['max(als)'] = int()

# %% [markdown]
# nest['min(als)'] = int()

# %% [markdown]
# nest['max(tp0)'] = int()

# %% [markdown]
# nest['min(tp0)'] = int()

# %% [markdown]
# nest['min(tp0)'] = int()

# %% [markdown]
# nest['min(tp1)'] = int()

# %% [markdown]
# nest['max(tp1)'] = int()

# %% [markdown]
# nest['min(tp2)'] = int()

# %% [markdown]
# nest['max(tp2)'] = int()

# %% [markdown]
# nest['min(tp1)'] = int()

# %% [markdown]
# nest['min(tp3)'] = int()

# %%
import pandas_profiling
pandas_profiling.ProfileReport(nest)
# Out:
# C:\Users\Marko\anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...

# %%
weather = pd.read_csv('weather.csv')

# %%
weather.head()
# Out:
#        STATION                                    NAME  LATITUDE  LONGITUDE  \
# 0  USW00012918  HOUSTON WILLIAM P HOBBY AIRPORT, TX US  29.63806  -95.28194
# 1  USW00012918  HOUSTON WILLIAM P HOBBY AIRPORT, TX US  29.63806  -95.28194
# 2  USW00012918  HOUSTON WILLIAM P HOBBY AIRPORT, TX US  29.63806  -95.28194
# 3  USW00012918  HOUSTON WILLIAM P HOBBY AIRPORT, TX US  29.63806  -95.28194
# 4  USW00012918  HOUSTON WILLIAM P HOBBY AIRPORT, TX US  29.63806  -95.28194
#
#    ELEVATION      DATE  AWND AWND_ATTRIBUTES    PGTM PGTM_ATTRIBUTES  ...  \
# 0       13.4  2/1/2018   3.8             ,,W  1131.0             ,,W  ...
# 1       13.4  2/2/2018   6.7             ,,W   446.0             ,,W  ...
# 2       13.4  2/3/2018   3.0             ,,W  1215.0             ,,W  ...
# 3       13.4  2/4/2018   3.1             ,,W   125.0             ,,W  ...
# 4       13.4  2/5/2018   3.4             ,,W  1111.0             ,,W  ...
#
# ...

# %%
weather.dtypes
# Out:
# STATION             object
# NAME                object
# LATITUDE           float64
# LONGITUDE          float64
# ELEVATION          float64
# DATE                object
# AWND               float64
# AWND_ATTRIBUTES     object
# PGTM               float64
# PGTM_ATTRIBUTES     object
# PRCP               float64
# PRCP_ATTRIBUTES     object
# SNOW               float64
# SNOW_ATTRIBUTES     object
# SNWD               float64
# SNWD_ATTRIBUTES     object
# TAVG               float64
# TAVG_ATTRIBUTES     object
# TMAX               float64
# TMAX_ATTRIBUTES     object
# TMIN               float64
# TMIN_ATTRIBUTES     object
# WDF2               float64
# WDF2_ATTRIBUTES     object
# WDF5               float64
# WDF5_ATTRIBUTES     object
# WSF2               float64
# WSF2_ATTRIBUTES     object
# WSF5               float64
# WSF5_ATTRIBUTES     object
# dtype: object

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30601 entries, 0 to 30600
# Data columns (total 30 columns):
# STATION            779 non-null object
# NAME               779 non-null object
# LATITUDE           779 non-null float64
# LONGITUDE          779 non-null float64
# ELEVATION          779 non-null float64
# DATE               779 non-null object
# AWND               779 non-null float64
# AWND_ATTRIBUTES    779 non-null object
# PGTM               28 non-null float64
# PGTM_ATTRIBUTES    28 non-null object
# PRCP               779 non-null float64
# PRCP_ATTRIBUTES    779 non-null object
# SNOW               770 non-null float64
# SNOW_ATTRIBUTES    770 non-null object
# SNWD               777 non-null float64
# SNWD_ATTRIBUTES    777 non-null object
# TAVG               778 non-null float64
# TAVG_ATTRIBUTES    778 non-null object
# TMAX               779 non-null float64
# TMAX_ATTRIBUTES    779 non-null object
# TMIN               779 non-null float64
# ...

# %%
import pandas_profiling
pandas_profiling.ProfileReport(weather)
# Out:
# C:\Users\Marko\anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...
